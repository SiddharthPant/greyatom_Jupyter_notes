# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
with open('data/college-majors/recent-grads.csv') as csv_file:
    recent_grads = pd.read_csv(csv_file, index_col='Rank')
    
recent_grads.iloc[0]
# Out:
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 1, dtype: object

# %%
recent_grads.head()
# Out:
#       Major_code                                      Major    Total      Men  \
# Rank
# 1           2419                      PETROLEUM ENGINEERING   2339.0   2057.0
# 2           2416             MINING AND MINERAL ENGINEERING    756.0    679.0
# 3           2415                  METALLURGICAL ENGINEERING    856.0    725.0
# 4           2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0   1123.0
# 5           2405                       CHEMICAL ENGINEERING  32260.0  21239.0
#
#         Women Major_category  ShareWomen  Sample_size  Employed  Full_time  \
# Rank
# 1       282.0    Engineering    0.120564           36      1976       1849
# 2        77.0    Engineering    0.101852            7       640        556
# 3       131.0    Engineering    0.153037            3       648        558
# 4       135.0    Engineering    0.107313           16       758       1069
# 5     11021.0    Engineering    0.341631          289     25694      23170
#
# ...

# %%
recent_grads.tail()
# Out:
#       Major_code                   Major   Total     Men   Women  \
# Rank
# 169         3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 170         5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 171         5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 172         5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 173         3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                 Major_category  ShareWomen  Sample_size  Employed  Full_time  \
# Rank
# 169     Biology & Life Science    0.637293           47      6259       5043
# 170   Psychology & Social Work    0.817099            7      2125       1848
# 171   Psychology & Social Work    0.799859           13      2101       1724
# 172   Psychology & Social Work    0.798746           21      3777       3154
# 173                  Education    0.877960            2       742        593
#
#       Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# Rank
# ...

# %%
recent_grads.describe()
# Out:
#         Major_code          Total            Men          Women  ShareWomen  \
# count   173.000000     172.000000     172.000000     172.000000  172.000000
# mean   3879.815029   39370.081395   16723.406977   22646.674419    0.522223
# std    1687.753140   63483.491009   28122.433474   41057.330740    0.231205
# min    1100.000000     124.000000     119.000000       0.000000    0.000000
# 25%    2403.000000    4549.750000    2177.500000    1778.250000    0.336026
# 50%    3608.000000   15104.000000    5434.000000    8386.500000    0.534024
# 75%    5503.000000   38909.750000   14631.000000   22553.750000    0.703299
# max    6403.000000  393735.000000  173809.000000  307087.000000    0.968954
#
#        Sample_size       Employed      Full_time      Part_time  \
# count   173.000000     173.000000     173.000000     173.000000
# mean    356.080925   31192.763006   26029.306358    8832.398844
# std     618.361022   50675.002241   42869.655092   14648.179473
# ...

# %%
raw_data_count = recent_grads.shape[0]

# %%
recent_grads = recent_grads.dropna(axis='index')

# %% [markdown]
# # 2: Pandas, Scatter Plots

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(20,24))
for i, col in enumerate(cols):
    ax = fig.add_subplot(4,2,i + 1)
    ax = recent_grads[col].plot.hist(rot=45, grid=True, legend=True, fontsize=14)
#     ax.set(xlabel=col)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Women','Men']], figsize=(10,10), grid=True, marker='.')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bdb0a790>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bd823f10>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10), grid=True, marker='.')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bd93a810>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bd4e72d0>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10), grid=True, marker='.')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bd5ff3d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff7bcf4da10>]], dtype=object)

# %%
recent_grads[:5]['Women'].plot.bar()

# %%
recent_grads[:10].plot.barh(x='Major', y='ShareWomen')
recent_grads[163:].plot.barh(x='Major', y='ShareWomen')
