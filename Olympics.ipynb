# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
dir_path = 'olympics/'
medals = pd.read_csv('{}{}'.format(dir_path, 'olympics.csv'),index_col=0, header=1, skiprows=0)
col_names = {
    '01 !': 'Gold',
    '02 !': 'Silver',
    '03 !': 'Bronze',
    '01 !.1': 'Gold.1',
    '02 !.1': 'Silver.1',
    '03 !.1': 'Bronze.1',
    '01 !.2': 'Gold.2',
    '02 !.2': 'Silver.2',
    '03 !.2': 'Bronze.2'
}
medals = medals.rename(columns = col_names)
# import simplejson
# f = open('output.txt', 'w')
# simplejson.dump(list(medals.index), f)
# f.close()

# %%
arr = medals.index.str.split('(')
arr[0][0].strip()
# Out:
# 'Afghanistan'

# %%
medals.index = [arr[0].strip() for arr in medals.index.str.split('(')]
# medals

# %%
medals2 = medals.drop('Totals')

# %%
medals2
# Out:
#                                   # Summer  Gold  Silver  Bronze  Total  \
# Afghanistan                             13     0       0       2      2
# Algeria                                 12     5       2       8     15
# Argentina                               23    18      24      28     70
# Armenia                                  5     1       2       9     12
# Australasia                              2     3       4       5     12
# Australia                               25   139     152     177    468
# Austria                                 26    18      33      35     86
# Azerbaijan                               5     6       5      15     26
# Bahamas                                 15     5       2       5     12
# Bahrain                                  8     0       0       1      1
# Barbados                                11     0       0       1      1
# Belarus                                  5    12      24      39     75
# ...

# %%
medals2['Combined total'].idxmax()
# Out:
# 'United States'

# %%
medals.iloc[0]
# Out:
# # Summer          13
# Gold               0
# Silver             0
# Bronze             2
# Total              2
# # Winter           0
# Gold.1             0
# Silver.1           0
# Bronze.1           0
# Total.1            0
# # Games           13
# Gold.2             0
# Silver.2           0
# Bronze.2           2
# Combined total     2
# Name: Afghanistan, dtype: int64

# %%
medals2['Gold'].idxmax()
# Out:
# 'United States'

# %%
(medals2['Gold'] - medals2['Gold.1']).abs().idxmax()
# Out:
# 'United States'

# %%
Points = medals2['Gold.2'] * 3 + medals2['Silver.2'] * 2 + medals2['Bronze.2']

# %%
Points['Australia']
# Out:
# 923

# %%
xyz = res.loc[['Australia']]
xyz
# Out:
#            # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  \
# Australia        25   139     152     177    468        18       5         3
#
#            Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Australia         4       12       43     144       155       181
#
#            Combined total
# Australia             480

# %%
pd.__version__
