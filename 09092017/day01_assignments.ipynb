# %% [markdown]
# # Task 1: Setting up Twitter API
#
# Here is what we want to accomplish:
#
# 1. Set up a "Twitter" account
# 2. Get the access tokens
# 3. Set up the access tokens
#
#
# - All we need to do is visit this page: [Twitter](https://twitter.com/signup?lang=en) and fill in the details to sign up! (_Note: No need to do this if you already are a Twitterati!_)
#
# - Next step is to get to the Twitter Application Management page: [Twitter Applicaition Management](https://apps.twitter.com/)
#
# - Sign in with the credentials that you used to create your Twitter Id.
#
# - Below is the homepage that you'll see. It won't have any applications, so click on _Create New Apps_.
#
# <br>
# <div align="center"><img src="./images/twitter01.png"/></div>
#
# - It would take you to the _Create an application_ page. (_see below_)
#
# <br>
# <div align="center"><img src="./images/twitter02.png"/></div>
#
# - Fill up all the details and click on _Create Application_, you'll be redirected to the app management page. (_See below_)
#
# <br>
# <div align="center"><img src="./images/twitter03.png"/></div>
#
#
# - Click on the _Keys and Access Tokens_ tab, you would see two sections:
#     * Application Settings
#     * Your Access Token
#
#
# - _Application Settings_ has the tokens that the application needs to authenticate your api call against.
#
# <br>
# <div align="center">
# <img src="./images/twitter04.png"/>
# </div>
#
# - _Access Tokens_ need to be created for a freshly minted Twitter app. So go on and click the _Create my access token_.
#
# <br>
# <div align="center">
# <img src="./images/twitter05.png"/>
# </div>
#
# - You are now set to use it for exciting applications!

# %% [markdown]
# # Task 2: Setting up GitHub API
#
# Here is what we want to accomplish:
#
# 1. Setup a Github account
# 2. Get the tokens
# 3. Setup the tokens
#
# - Visit the website: [Github](https://github.com/)
# - Click on _Sign up_ and fill out all the details in __Step 1: Set up a personal account__, get yourself a cool github id! (_Note: You can choose to continue with your previous id, if you had one).
#
# - __Step 2: Choose your plan__, let the default be _Unlimited public repositories for free_ and click on _Continue_
#
# - __Step 3: Tailor your experience__, fill in the details (_or you could skip this_).
#
#
# <br>
# <div align="center">
# <img src="./images/github01.png"/>
# </div>
#
# - Click on _Settings_ and scroll-down to find _Developer settings_.
#
# <br>
# <div align="center">
# <img src="./images/github02.png"/>
# </div>
#
# - Register a new application, that would take you to the page below:
#
# <br>
# <div align="center">
# <img src="./images/github03.png"/>
# </div>
#
# - Fill in the details, just the same as while creating a Twitter app, and register your application.
#
# - Your `Client ID` and `Client Secret` are now created for the demo application. (_see below_)
#
# <br>
# <div align="center">
# <img src="./images/github04.png"/>
# </div>

# %% [markdown]
# # Task 3: GitHub Recommender System
#
# In this task, we'll build a very simple recommender system for GitHub. We'll look at the GitHub profile of a given user and use that information to generate repository recommendations (other GitHub repository that user may be interested in) for that user.
#
# Task: [For this GH user](https://api.github.com/users/karpathy/repos), answer the following questions:
#
# ## a. How many GH repos does the user have?

# %%
import requests

url = "https://api.github.com/users/karpathy"
request = requests.get(url)

# %%
request.status_code
# Out:
# 200

# %%
request.json()
# Out:
# {u'avatar_url': u'https://avatars3.githubusercontent.com/u/241138?v=4',
#  u'bio': None,
#  u'blog': u'twitter.com/karpathy',
#  u'company': None,
#  u'created_at': u'2010-04-10T17:55:32Z',
#  u'email': None,
#  u'events_url': u'https://api.github.com/users/karpathy/events{/privacy}',
#  u'followers': 12264,
#  u'followers_url': u'https://api.github.com/users/karpathy/followers',
#  u'following': 5,
#  u'following_url': u'https://api.github.com/users/karpathy/following{/other_user}',
#  u'gists_url': u'https://api.github.com/users/karpathy/gists{/gist_id}',
#  u'gravatar_id': u'',
#  u'hireable': None,
#  u'html_url': u'https://github.com/karpathy',
#  u'id': 241138,
#  u'location': u'Stanford',
#  u'login': u'karpathy',
#  u'name': u'Andrej',
#  u'organizations_url': u'https://api.github.com/users/karpathy/orgs',
#  u'public_gists': 7,
#  u'public_repos': 29,
#  u'received_events_url': u'https://api.github.com/users/karpathy/received_events',
#  u'repos_url': u'https://api.github.com/users/karpathy/repos',
#  u'site_admin': False,
#  u'starred_url': u'https://api.github.com/users/karpathy/starred{/owner}{/repo}',
#  u'subscriptions_url': u'https://api.github.com/users/karpathy/subscriptions',
#  u'type': u'User',
#  u'updated_at': u'2017-08-14T19:04:01Z',
#  u'url': u'https://api.github.com/users/karpathy'}

# %%
repositories = request.json()

# %%
type(repositories)
# Out:
# dict

# %%
repositories.get('public_repos')
# Out:
# 29

# %% [markdown]
# ## b. How many GH repos has the user liked

# %%
import requests

url = u'https://api.github.com/users/karpathy/starred'
request = requests.get(url)

# %%
Starred_Request = request.json()
Starred_Request
# Out:
# [{u'archive_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/branches{/branch}',
#   u'clone_url': u'https://github.com/albanie/SIGBOVIK17-GUNs.git',
#   u'collaborators_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/contributors',
#   u'created_at': u'2017-03-04T20:15:39Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/deployments',
#   u'description': u'Supporting public code for SIGBOVIK17 submission',
#   u'downloads_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/downloads',
#   u'events_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/events',
#   u'fork': False,
#   u'forks': 13,
#   u'forks_count': 13,
#   u'forks_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/forks',
#   u'full_name': u'albanie/SIGBOVIK17-GUNs',
#   u'git_commits_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/git/tags{/sha}',
#   u'git_url': u'git://github.com/albanie/SIGBOVIK17-GUNs.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/hooks',
#   u'html_url': u'https://github.com/albanie/SIGBOVIK17-GUNs',
#   u'id': 83921770,
#   u'issue_comment_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/labels{/name}',
#   u'language': u'Python',
#   u'languages_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/languages',
#   u'merges_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/merges',
#   u'milestones_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'SIGBOVIK17-GUNs',
#   u'notifications_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/notifications{?since,all,participating}',
#   u'open_issues': 3,
#   u'open_issues_count': 3,
#   u'owner': {u'avatar_url': u'https://avatars0.githubusercontent.com/u/4395064?v=4',
#    u'events_url': u'https://api.github.com/users/albanie/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/albanie/followers',
#    u'following_url': u'https://api.github.com/users/albanie/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/albanie/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/albanie',
#    u'id': 4395064,
#    u'login': u'albanie',
#    u'organizations_url': u'https://api.github.com/users/albanie/orgs',
#    u'received_events_url': u'https://api.github.com/users/albanie/received_events',
#    u'repos_url': u'https://api.github.com/users/albanie/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/albanie/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/albanie/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/albanie'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/pulls{/number}',
#   u'pushed_at': u'2017-03-08T09:34:53Z',
#   u'releases_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/releases{/id}',
#   u'size': 8,
#   u'ssh_url': u'git@github.com:albanie/SIGBOVIK17-GUNs.git',
#   u'stargazers_count': 157,
#   u'stargazers_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/subscription',
#   u'svn_url': u'https://github.com/albanie/SIGBOVIK17-GUNs',
#   u'tags_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/tags',
#   u'teams_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/teams',
#   u'trees_url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs/git/trees{/sha}',
#   u'updated_at': u'2017-08-09T07:43:40Z',
#   u'url': u'https://api.github.com/repos/albanie/SIGBOVIK17-GUNs',
#   u'watchers': 157,
#   u'watchers_count': 157},
#  {u'archive_url': u'https://api.github.com/repos/sourcegraph/thyme/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/sourcegraph/thyme/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/sourcegraph/thyme/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/sourcegraph/thyme/branches{/branch}',
#   u'clone_url': u'https://github.com/sourcegraph/thyme.git',
#   u'collaborators_url': u'https://api.github.com/repos/sourcegraph/thyme/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/sourcegraph/thyme/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/sourcegraph/thyme/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/sourcegraph/thyme/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/sourcegraph/thyme/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/sourcegraph/thyme/contributors',
#   u'created_at': u'2016-08-08T06:15:10Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/sourcegraph/thyme/deployments',
#   u'description': u'Automatically track which applications you use and for how long.',
#   u'downloads_url': u'https://api.github.com/repos/sourcegraph/thyme/downloads',
#   u'events_url': u'https://api.github.com/repos/sourcegraph/thyme/events',
#   u'fork': False,
#   u'forks': 51,
#   u'forks_count': 51,
#   u'forks_url': u'https://api.github.com/repos/sourcegraph/thyme/forks',
#   u'full_name': u'sourcegraph/thyme',
#   u'git_commits_url': u'https://api.github.com/repos/sourcegraph/thyme/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/sourcegraph/thyme/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/sourcegraph/thyme/git/tags{/sha}',
#   u'git_url': u'git://github.com/sourcegraph/thyme.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/sourcegraph/thyme/hooks',
#   u'html_url': u'https://github.com/sourcegraph/thyme',
#   u'id': 65177522,
#   u'issue_comment_url': u'https://api.github.com/repos/sourcegraph/thyme/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/sourcegraph/thyme/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/sourcegraph/thyme/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/sourcegraph/thyme/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/sourcegraph/thyme/labels{/name}',
#   u'language': u'Go',
#   u'languages_url': u'https://api.github.com/repos/sourcegraph/thyme/languages',
#   u'merges_url': u'https://api.github.com/repos/sourcegraph/thyme/merges',
#   u'milestones_url': u'https://api.github.com/repos/sourcegraph/thyme/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'thyme',
#   u'notifications_url': u'https://api.github.com/repos/sourcegraph/thyme/notifications{?since,all,participating}',
#   u'open_issues': 28,
#   u'open_issues_count': 28,
#   u'owner': {u'avatar_url': u'https://avatars0.githubusercontent.com/u/3979584?v=4',
#    u'events_url': u'https://api.github.com/users/sourcegraph/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/sourcegraph/followers',
#    u'following_url': u'https://api.github.com/users/sourcegraph/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/sourcegraph/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/sourcegraph',
#    u'id': 3979584,
#    u'login': u'sourcegraph',
#    u'organizations_url': u'https://api.github.com/users/sourcegraph/orgs',
#    u'received_events_url': u'https://api.github.com/users/sourcegraph/received_events',
#    u'repos_url': u'https://api.github.com/users/sourcegraph/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/sourcegraph/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/sourcegraph/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/sourcegraph'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/sourcegraph/thyme/pulls{/number}',
#   u'pushed_at': u'2016-11-10T16:13:14Z',
#   u'releases_url': u'https://api.github.com/repos/sourcegraph/thyme/releases{/id}',
#   u'size': 381,
#   u'ssh_url': u'git@github.com:sourcegraph/thyme.git',
#   u'stargazers_count': 1879,
#   u'stargazers_url': u'https://api.github.com/repos/sourcegraph/thyme/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/sourcegraph/thyme/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/sourcegraph/thyme/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/sourcegraph/thyme/subscription',
#   u'svn_url': u'https://github.com/sourcegraph/thyme',
#   u'tags_url': u'https://api.github.com/repos/sourcegraph/thyme/tags',
#   u'teams_url': u'https://api.github.com/repos/sourcegraph/thyme/teams',
#   u'trees_url': u'https://api.github.com/repos/sourcegraph/thyme/git/trees{/sha}',
#   u'updated_at': u'2017-09-07T10:37:26Z',
#   u'url': u'https://api.github.com/repos/sourcegraph/thyme',
#   u'watchers': 1879,
#   u'watchers_count': 1879},
#  {u'archive_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/branches{/branch}',
#   u'clone_url': u'https://github.com/nicolashery/mac-dev-setup.git',
#   u'collaborators_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/contributors',
#   u'created_at': u'2012-12-01T19:16:53Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/deployments',
#   u'description': u"A beginner's guide to setting up a development environment on Mac OS X",
#   u'downloads_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/downloads',
#   u'events_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/events',
#   u'fork': False,
#   u'forks': 657,
#   u'forks_count': 657,
#   u'forks_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/forks',
#   u'full_name': u'nicolashery/mac-dev-setup',
#   u'git_commits_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/git/tags{/sha}',
#   u'git_url': u'git://github.com/nicolashery/mac-dev-setup.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/hooks',
#   u'html_url': u'https://github.com/nicolashery/mac-dev-setup',
#   u'id': 6958220,
#   u'issue_comment_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/labels{/name}',
#   u'language': u'Shell',
#   u'languages_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/languages',
#   u'merges_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/merges',
#   u'milestones_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'mac-dev-setup',
#   u'notifications_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/notifications{?since,all,participating}',
#   u'open_issues': 36,
#   u'open_issues_count': 36,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/1306536?v=4',
#    u'events_url': u'https://api.github.com/users/nicolashery/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/nicolashery/followers',
#    u'following_url': u'https://api.github.com/users/nicolashery/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/nicolashery/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/nicolashery',
#    u'id': 1306536,
#    u'login': u'nicolashery',
#    u'organizations_url': u'https://api.github.com/users/nicolashery/orgs',
#    u'received_events_url': u'https://api.github.com/users/nicolashery/received_events',
#    u'repos_url': u'https://api.github.com/users/nicolashery/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/nicolashery/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/nicolashery/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/nicolashery'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/pulls{/number}',
#   u'pushed_at': u'2017-08-04T10:31:03Z',
#   u'releases_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/releases{/id}',
#   u'size': 59,
#   u'ssh_url': u'git@github.com:nicolashery/mac-dev-setup.git',
#   u'stargazers_count': 3211,
#   u'stargazers_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/subscription',
#   u'svn_url': u'https://github.com/nicolashery/mac-dev-setup',
#   u'tags_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/tags',
#   u'teams_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/teams',
#   u'trees_url': u'https://api.github.com/repos/nicolashery/mac-dev-setup/git/trees{/sha}',
#   u'updated_at': u'2017-09-08T14:08:44Z',
#   u'url': u'https://api.github.com/repos/nicolashery/mac-dev-setup',
#   u'watchers': 3211,
#   u'watchers_count': 3211},
#  {u'archive_url': u'https://api.github.com/repos/jcjohnson/densecap/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/jcjohnson/densecap/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/jcjohnson/densecap/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/jcjohnson/densecap/branches{/branch}',
#   u'clone_url': u'https://github.com/jcjohnson/densecap.git',
#   u'collaborators_url': u'https://api.github.com/repos/jcjohnson/densecap/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/jcjohnson/densecap/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/jcjohnson/densecap/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/jcjohnson/densecap/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/jcjohnson/densecap/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/jcjohnson/densecap/contributors',
#   u'created_at': u'2015-12-01T02:10:48Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/jcjohnson/densecap/deployments',
#   u'description': u'Dense image captioning in Torch',
#   u'downloads_url': u'https://api.github.com/repos/jcjohnson/densecap/downloads',
#   u'events_url': u'https://api.github.com/repos/jcjohnson/densecap/events',
#   u'fork': False,
#   u'forks': 265,
#   u'forks_count': 265,
#   u'forks_url': u'https://api.github.com/repos/jcjohnson/densecap/forks',
#   u'full_name': u'jcjohnson/densecap',
#   u'git_commits_url': u'https://api.github.com/repos/jcjohnson/densecap/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/jcjohnson/densecap/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/jcjohnson/densecap/git/tags{/sha}',
#   u'git_url': u'git://github.com/jcjohnson/densecap.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/jcjohnson/densecap/hooks',
#   u'html_url': u'https://github.com/jcjohnson/densecap',
#   u'id': 47159356,
#   u'issue_comment_url': u'https://api.github.com/repos/jcjohnson/densecap/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/jcjohnson/densecap/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/jcjohnson/densecap/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/jcjohnson/densecap/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/jcjohnson/densecap/labels{/name}',
#   u'language': u'Jupyter Notebook',
#   u'languages_url': u'https://api.github.com/repos/jcjohnson/densecap/languages',
#   u'merges_url': u'https://api.github.com/repos/jcjohnson/densecap/merges',
#   u'milestones_url': u'https://api.github.com/repos/jcjohnson/densecap/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'densecap',
#   u'notifications_url': u'https://api.github.com/repos/jcjohnson/densecap/notifications{?since,all,participating}',
#   u'open_issues': 31,
#   u'open_issues_count': 31,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/2718714?v=4',
#    u'events_url': u'https://api.github.com/users/jcjohnson/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/jcjohnson/followers',
#    u'following_url': u'https://api.github.com/users/jcjohnson/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/jcjohnson/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/jcjohnson',
#    u'id': 2718714,
#    u'login': u'jcjohnson',
#    u'organizations_url': u'https://api.github.com/users/jcjohnson/orgs',
#    u'received_events_url': u'https://api.github.com/users/jcjohnson/received_events',
#    u'repos_url': u'https://api.github.com/users/jcjohnson/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/jcjohnson/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/jcjohnson/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/jcjohnson'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/jcjohnson/densecap/pulls{/number}',
#   u'pushed_at': u'2017-06-13T20:24:54Z',
#   u'releases_url': u'https://api.github.com/repos/jcjohnson/densecap/releases{/id}',
#   u'size': 9063,
#   u'ssh_url': u'git@github.com:jcjohnson/densecap.git',
#   u'stargazers_count': 862,
#   u'stargazers_url': u'https://api.github.com/repos/jcjohnson/densecap/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/jcjohnson/densecap/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/jcjohnson/densecap/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/jcjohnson/densecap/subscription',
#   u'svn_url': u'https://github.com/jcjohnson/densecap',
#   u'tags_url': u'https://api.github.com/repos/jcjohnson/densecap/tags',
#   u'teams_url': u'https://api.github.com/repos/jcjohnson/densecap/teams',
#   u'trees_url': u'https://api.github.com/repos/jcjohnson/densecap/git/trees{/sha}',
#   u'updated_at': u'2017-09-08T10:04:01Z',
#   u'url': u'https://api.github.com/repos/jcjohnson/densecap',
#   u'watchers': 862,
#   u'watchers_count': 862},
#  {u'archive_url': u'https://api.github.com/repos/dritchie/adnn/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/dritchie/adnn/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/dritchie/adnn/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/dritchie/adnn/branches{/branch}',
#   u'clone_url': u'https://github.com/dritchie/adnn.git',
#   u'collaborators_url': u'https://api.github.com/repos/dritchie/adnn/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/dritchie/adnn/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/dritchie/adnn/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/dritchie/adnn/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/dritchie/adnn/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/dritchie/adnn/contributors',
#   u'created_at': u'2015-10-31T00:54:44Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/dritchie/adnn/deployments',
#   u'description': u'Javascript neural networks on top of general scalar/tensor reverse-mode automatic differentiation.',
#   u'downloads_url': u'https://api.github.com/repos/dritchie/adnn/downloads',
#   u'events_url': u'https://api.github.com/repos/dritchie/adnn/events',
#   u'fork': False,
#   u'forks': 25,
#   u'forks_count': 25,
#   u'forks_url': u'https://api.github.com/repos/dritchie/adnn/forks',
#   u'full_name': u'dritchie/adnn',
#   u'git_commits_url': u'https://api.github.com/repos/dritchie/adnn/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/dritchie/adnn/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/dritchie/adnn/git/tags{/sha}',
#   u'git_url': u'git://github.com/dritchie/adnn.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/dritchie/adnn/hooks',
#   u'html_url': u'https://github.com/dritchie/adnn',
#   u'id': 45283644,
#   u'issue_comment_url': u'https://api.github.com/repos/dritchie/adnn/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/dritchie/adnn/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/dritchie/adnn/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/dritchie/adnn/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/dritchie/adnn/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/dritchie/adnn/languages',
#   u'merges_url': u'https://api.github.com/repos/dritchie/adnn/merges',
#   u'milestones_url': u'https://api.github.com/repos/dritchie/adnn/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'adnn',
#   u'notifications_url': u'https://api.github.com/repos/dritchie/adnn/notifications{?since,all,participating}',
#   u'open_issues': 4,
#   u'open_issues_count': 4,
#   u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/2229830?v=4',
#    u'events_url': u'https://api.github.com/users/dritchie/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/dritchie/followers',
#    u'following_url': u'https://api.github.com/users/dritchie/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/dritchie/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/dritchie',
#    u'id': 2229830,
#    u'login': u'dritchie',
#    u'organizations_url': u'https://api.github.com/users/dritchie/orgs',
#    u'received_events_url': u'https://api.github.com/users/dritchie/received_events',
#    u'repos_url': u'https://api.github.com/users/dritchie/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/dritchie/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/dritchie/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/dritchie'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/dritchie/adnn/pulls{/number}',
#   u'pushed_at': u'2017-08-18T19:15:13Z',
#   u'releases_url': u'https://api.github.com/repos/dritchie/adnn/releases{/id}',
#   u'size': 290,
#   u'ssh_url': u'git@github.com:dritchie/adnn.git',
#   u'stargazers_count': 198,
#   u'stargazers_url': u'https://api.github.com/repos/dritchie/adnn/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/dritchie/adnn/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/dritchie/adnn/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/dritchie/adnn/subscription',
#   u'svn_url': u'https://github.com/dritchie/adnn',
#   u'tags_url': u'https://api.github.com/repos/dritchie/adnn/tags',
#   u'teams_url': u'https://api.github.com/repos/dritchie/adnn/teams',
#   u'trees_url': u'https://api.github.com/repos/dritchie/adnn/git/trees{/sha}',
#   u'updated_at': u'2017-08-12T19:13:44Z',
#   u'url': u'https://api.github.com/repos/dritchie/adnn',
#   u'watchers': 198,
#   u'watchers_count': 198},
#  {u'archive_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/branches{/branch}',
#   u'clone_url': u'https://github.com/yueatsprograms/Stochastic_Depth.git',
#   u'collaborators_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/contributors',
#   u'created_at': u'2016-04-01T20:50:07Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/deployments',
#   u'description': u'Code for "Deep Networks with Stochastic Depth"',
#   u'downloads_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/downloads',
#   u'events_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/events',
#   u'fork': False,
#   u'forks': 72,
#   u'forks_count': 72,
#   u'forks_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/forks',
#   u'full_name': u'yueatsprograms/Stochastic_Depth',
#   u'git_commits_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/git/tags{/sha}',
#   u'git_url': u'git://github.com/yueatsprograms/Stochastic_Depth.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'http://arxiv.org/abs/1603.09382',
#   u'hooks_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/hooks',
#   u'html_url': u'https://github.com/yueatsprograms/Stochastic_Depth',
#   u'id': 55261515,
#   u'issue_comment_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/labels{/name}',
#   u'language': u'Lua',
#   u'languages_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/languages',
#   u'merges_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/merges',
#   u'milestones_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'Stochastic_Depth',
#   u'notifications_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/5546216?v=4',
#    u'events_url': u'https://api.github.com/users/yueatsprograms/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/yueatsprograms/followers',
#    u'following_url': u'https://api.github.com/users/yueatsprograms/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/yueatsprograms/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/yueatsprograms',
#    u'id': 5546216,
#    u'login': u'yueatsprograms',
#    u'organizations_url': u'https://api.github.com/users/yueatsprograms/orgs',
#    u'received_events_url': u'https://api.github.com/users/yueatsprograms/received_events',
#    u'repos_url': u'https://api.github.com/users/yueatsprograms/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/yueatsprograms/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/yueatsprograms/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/yueatsprograms'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/pulls{/number}',
#   u'pushed_at': u'2017-04-11T21:30:07Z',
#   u'releases_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/releases{/id}',
#   u'size': 19,
#   u'ssh_url': u'git@github.com:yueatsprograms/Stochastic_Depth.git',
#   u'stargazers_count': 378,
#   u'stargazers_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/subscription',
#   u'svn_url': u'https://github.com/yueatsprograms/Stochastic_Depth',
#   u'tags_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/tags',
#   u'teams_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/teams',
#   u'trees_url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth/git/trees{/sha}',
#   u'updated_at': u'2017-08-22T10:06:56Z',
#   u'url': u'https://api.github.com/repos/yueatsprograms/Stochastic_Depth',
#   u'watchers': 378,
#   u'watchers_count': 378},
#  {u'archive_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/branches{/branch}',
#   u'clone_url': u'https://github.com/jcjohnson/torch-rnn.git',
#   u'collaborators_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/contributors',
#   u'created_at': u'2016-02-14T06:14:36Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/deployments',
#   u'description': u'Efficient, reusable RNNs and LSTMs for torch',
#   u'downloads_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/downloads',
#   u'events_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/events',
#   u'fork': False,
#   u'forks': 389,
#   u'forks_count': 389,
#   u'forks_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/forks',
#   u'full_name': u'jcjohnson/torch-rnn',
#   u'git_commits_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/git/tags{/sha}',
#   u'git_url': u'git://github.com/jcjohnson/torch-rnn.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/hooks',
#   u'html_url': u'https://github.com/jcjohnson/torch-rnn',
#   u'id': 51682497,
#   u'issue_comment_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/labels{/name}',
#   u'language': u'Lua',
#   u'languages_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/languages',
#   u'merges_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/merges',
#   u'milestones_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'torch-rnn',
#   u'notifications_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/notifications{?since,all,participating}',
#   u'open_issues': 94,
#   u'open_issues_count': 94,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/2718714?v=4',
#    u'events_url': u'https://api.github.com/users/jcjohnson/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/jcjohnson/followers',
#    u'following_url': u'https://api.github.com/users/jcjohnson/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/jcjohnson/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/jcjohnson',
#    u'id': 2718714,
#    u'login': u'jcjohnson',
#    u'organizations_url': u'https://api.github.com/users/jcjohnson/orgs',
#    u'received_events_url': u'https://api.github.com/users/jcjohnson/received_events',
#    u'repos_url': u'https://api.github.com/users/jcjohnson/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/jcjohnson/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/jcjohnson/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/jcjohnson'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/pulls{/number}',
#   u'pushed_at': u'2017-07-31T10:24:40Z',
#   u'releases_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/releases{/id}',
#   u'size': 846,
#   u'ssh_url': u'git@github.com:jcjohnson/torch-rnn.git',
#   u'stargazers_count': 1589,
#   u'stargazers_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/subscription',
#   u'svn_url': u'https://github.com/jcjohnson/torch-rnn',
#   u'tags_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/tags',
#   u'teams_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/teams',
#   u'trees_url': u'https://api.github.com/repos/jcjohnson/torch-rnn/git/trees{/sha}',
#   u'updated_at': u'2017-09-09T01:20:03Z',
#   u'url': u'https://api.github.com/repos/jcjohnson/torch-rnn',
#   u'watchers': 1589,
#   u'watchers_count': 1589},
#  {u'archive_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/branches{/branch}',
#   u'clone_url': u'https://github.com/facebook/fb.resnet.torch.git',
#   u'collaborators_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/contributors',
#   u'created_at': u'2016-01-12T20:29:16Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/deployments',
#   u'description': u'Torch implementation of ResNet from http://arxiv.org/abs/1512.03385 and training scripts',
#   u'downloads_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/downloads',
#   u'events_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/events',
#   u'fork': False,
#   u'forks': 451,
#   u'forks_count': 451,
#   u'forks_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/forks',
#   u'full_name': u'facebook/fb.resnet.torch',
#   u'git_commits_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/git/tags{/sha}',
#   u'git_url': u'git://github.com/facebook/fb.resnet.torch.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/hooks',
#   u'html_url': u'https://github.com/facebook/fb.resnet.torch',
#   u'id': 49527035,
#   u'issue_comment_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/labels{/name}',
#   u'language': u'Lua',
#   u'languages_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/languages',
#   u'merges_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/merges',
#   u'milestones_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'fb.resnet.torch',
#   u'notifications_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/notifications{?since,all,participating}',
#   u'open_issues': 51,
#   u'open_issues_count': 51,
#   u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/69631?v=4',
#    u'events_url': u'https://api.github.com/users/facebook/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/facebook/followers',
#    u'following_url': u'https://api.github.com/users/facebook/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/facebook/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/facebook',
#    u'id': 69631,
#    u'login': u'facebook',
#    u'organizations_url': u'https://api.github.com/users/facebook/orgs',
#    u'received_events_url': u'https://api.github.com/users/facebook/received_events',
#    u'repos_url': u'https://api.github.com/users/facebook/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/facebook/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/facebook/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/facebook'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/pulls{/number}',
#   u'pushed_at': u'2017-04-21T08:43:13Z',
#   u'releases_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/releases{/id}',
#   u'size': 95,
#   u'ssh_url': u'git@github.com:facebook/fb.resnet.torch.git',
#   u'stargazers_count': 1224,
#   u'stargazers_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/subscription',
#   u'svn_url': u'https://github.com/facebook/fb.resnet.torch',
#   u'tags_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/tags',
#   u'teams_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/teams',
#   u'trees_url': u'https://api.github.com/repos/facebook/fb.resnet.torch/git/trees{/sha}',
#   u'updated_at': u'2017-09-09T00:06:02Z',
#   u'url': u'https://api.github.com/repos/facebook/fb.resnet.torch',
#   u'watchers': 1224,
#   u'watchers_count': 1224},
#  {u'archive_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/branches{/branch}',
#   u'clone_url': u'https://github.com/pkmital/tensorflow_tutorials.git',
#   u'collaborators_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/contributors',
#   u'created_at': u'2016-02-03T04:01:40Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/deployments',
#   u'description': u'From the basics to slightly more interesting applications of Tensorflow',
#   u'downloads_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/downloads',
#   u'events_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/events',
#   u'fork': False,
#   u'forks': 779,
#   u'forks_count': 779,
#   u'forks_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/forks',
#   u'full_name': u'pkmital/tensorflow_tutorials',
#   u'git_commits_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/git/tags{/sha}',
#   u'git_url': u'git://github.com/pkmital/tensorflow_tutorials.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/hooks',
#   u'html_url': u'https://github.com/pkmital/tensorflow_tutorials',
#   u'id': 50972789,
#   u'issue_comment_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/labels{/name}',
#   u'language': u'Jupyter Notebook',
#   u'languages_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/languages',
#   u'merges_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/merges',
#   u'milestones_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'tensorflow_tutorials',
#   u'notifications_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/notifications{?since,all,participating}',
#   u'open_issues': 7,
#   u'open_issues_count': 7,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/429252?v=4',
#    u'events_url': u'https://api.github.com/users/pkmital/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/pkmital/followers',
#    u'following_url': u'https://api.github.com/users/pkmital/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/pkmital/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/pkmital',
#    u'id': 429252,
#    u'login': u'pkmital',
#    u'organizations_url': u'https://api.github.com/users/pkmital/orgs',
#    u'received_events_url': u'https://api.github.com/users/pkmital/received_events',
#    u'repos_url': u'https://api.github.com/users/pkmital/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/pkmital/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/pkmital/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/pkmital'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/pulls{/number}',
#   u'pushed_at': u'2017-03-22T03:48:04Z',
#   u'releases_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/releases{/id}',
#   u'size': 128046,
#   u'ssh_url': u'git@github.com:pkmital/tensorflow_tutorials.git',
#   u'stargazers_count': 3689,
#   u'stargazers_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/pkmital/tensorflow_tutorials/subscribers',
# ...
#   u'clone_url': u'https://github.com/IoannisAntonoglou/optimBench.git',
#   u'collaborators_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/contributors',
#   u'created_at': u'2014-01-07T12:16:22Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/deployments',
#   u'description': u'Benchmark testbed for assessing the performance of optimisation algorithms',
#   u'downloads_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/downloads',
#   u'events_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/events',
#   u'fork': False,
#   u'forks': 9,
#   u'forks_count': 9,
#   u'forks_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/forks',
#   u'full_name': u'IoannisAntonoglou/optimBench',
#   u'git_commits_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/git/tags{/sha}',
#   u'git_url': u'git://github.com/IoannisAntonoglou/optimBench.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/hooks',
#   u'html_url': u'https://github.com/IoannisAntonoglou/optimBench',
#   u'id': 15703577,
#   u'issue_comment_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/labels{/name}',
#   u'language': u'Lua',
#   u'languages_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/languages',
#   u'merges_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/merges',
#   u'milestones_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'optimBench',
#   u'notifications_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/notifications{?since,all,participating}',
#   u'open_issues': 2,
#   u'open_issues_count': 2,
#   u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/2656328?v=4',
#    u'events_url': u'https://api.github.com/users/IoannisAntonoglou/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/IoannisAntonoglou/followers',
#    u'following_url': u'https://api.github.com/users/IoannisAntonoglou/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/IoannisAntonoglou/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/IoannisAntonoglou',
#    u'id': 2656328,
#    u'login': u'IoannisAntonoglou',
#    u'organizations_url': u'https://api.github.com/users/IoannisAntonoglou/orgs',
#    u'received_events_url': u'https://api.github.com/users/IoannisAntonoglou/received_events',
#    u'repos_url': u'https://api.github.com/users/IoannisAntonoglou/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/IoannisAntonoglou/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/IoannisAntonoglou/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/IoannisAntonoglou'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/pulls{/number}',
#   u'pushed_at': u'2015-01-07T15:22:40Z',
#   u'releases_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/releases{/id}',
#   u'size': 233,
#   u'ssh_url': u'git@github.com:IoannisAntonoglou/optimBench.git',
#   u'stargazers_count': 55,
#   u'stargazers_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/subscription',
#   u'svn_url': u'https://github.com/IoannisAntonoglou/optimBench',
#   u'tags_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/tags',
#   u'teams_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/teams',
#   u'trees_url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench/git/trees{/sha}',
#   u'updated_at': u'2017-08-08T11:24:29Z',
#   u'url': u'https://api.github.com/repos/IoannisAntonoglou/optimBench',
#   u'watchers': 55,
#   u'watchers_count': 55},
#  {u'archive_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/branches{/branch}',
#   u'clone_url': u'https://github.com/jetpacapp/DeepBeliefSDK.git',
#   u'collaborators_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/contributors',
#   u'created_at': u'2014-04-02T23:14:07Z',
#   u'default_branch': u'gh-pages',
#   u'deployments_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/deployments',
#   u'description': u"The SDK for Jetpac's iOS Deep Belief image recognition framework",
#   u'downloads_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/downloads',
#   u'events_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/events',
#   u'fork': False,
#   u'forks': 460,
#   u'forks_count': 460,
#   u'forks_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/forks',
#   u'full_name': u'jetpacapp/DeepBeliefSDK',
#   u'git_commits_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/git/tags{/sha}',
#   u'git_url': u'git://github.com/jetpacapp/DeepBeliefSDK.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': True,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': None,
#   u'hooks_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/hooks',
#   u'html_url': u'https://github.com/jetpacapp/DeepBeliefSDK',
#   u'id': 18384763,
#   u'issue_comment_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/languages',
#   u'merges_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/merges',
#   u'milestones_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'DeepBeliefSDK',
#   u'notifications_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/notifications{?since,all,participating}',
#   u'open_issues': 57,
#   u'open_issues_count': 57,
#   u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/1399574?v=4',
#    u'events_url': u'https://api.github.com/users/jetpacapp/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/jetpacapp/followers',
#    u'following_url': u'https://api.github.com/users/jetpacapp/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/jetpacapp/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/jetpacapp',
#    u'id': 1399574,
#    u'login': u'jetpacapp',
#    u'organizations_url': u'https://api.github.com/users/jetpacapp/orgs',
#    u'received_events_url': u'https://api.github.com/users/jetpacapp/received_events',
#    u'repos_url': u'https://api.github.com/users/jetpacapp/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/jetpacapp/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/jetpacapp/subscriptions',
#    u'type': u'Organization',
#    u'url': u'https://api.github.com/users/jetpacapp'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/pulls{/number}',
#   u'pushed_at': u'2016-10-13T20:20:19Z',
#   u'releases_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/releases{/id}',
#   u'size': 225108,
#   u'ssh_url': u'git@github.com:jetpacapp/DeepBeliefSDK.git',
#   u'stargazers_count': 2800,
#   u'stargazers_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/subscription',
#   u'svn_url': u'https://github.com/jetpacapp/DeepBeliefSDK',
#   u'tags_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/tags',
#   u'teams_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/teams',
#   u'trees_url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK/git/trees{/sha}',
#   u'updated_at': u'2017-09-06T19:11:11Z',
#   u'url': u'https://api.github.com/repos/jetpacapp/DeepBeliefSDK',
#   u'watchers': 2800,
#   u'watchers_count': 2800},
#  {u'archive_url': u'https://api.github.com/repos/jnordberg/gif.js/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/jnordberg/gif.js/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/jnordberg/gif.js/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/jnordberg/gif.js/branches{/branch}',
#   u'clone_url': u'https://github.com/jnordberg/gif.js.git',
#   u'collaborators_url': u'https://api.github.com/repos/jnordberg/gif.js/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/jnordberg/gif.js/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/jnordberg/gif.js/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/jnordberg/gif.js/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/jnordberg/gif.js/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/jnordberg/gif.js/contributors',
#   u'created_at': u'2013-05-20T02:18:38Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/jnordberg/gif.js/deployments',
#   u'description': u'JavaScript GIF encoding library',
#   u'downloads_url': u'https://api.github.com/repos/jnordberg/gif.js/downloads',
#   u'events_url': u'https://api.github.com/repos/jnordberg/gif.js/events',
#   u'fork': False,
#   u'forks': 229,
#   u'forks_count': 229,
#   u'forks_url': u'https://api.github.com/repos/jnordberg/gif.js/forks',
#   u'full_name': u'jnordberg/gif.js',
#   u'git_commits_url': u'https://api.github.com/repos/jnordberg/gif.js/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/jnordberg/gif.js/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/jnordberg/gif.js/git/tags{/sha}',
#   u'git_url': u'git://github.com/jnordberg/gif.js.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': True,
#   u'has_projects': True,
#   u'has_wiki': True,
#   u'homepage': u'http://jnordberg.github.io/gif.js/',
#   u'hooks_url': u'https://api.github.com/repos/jnordberg/gif.js/hooks',
#   u'html_url': u'https://github.com/jnordberg/gif.js',
#   u'id': 10164495,
#   u'issue_comment_url': u'https://api.github.com/repos/jnordberg/gif.js/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/jnordberg/gif.js/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/jnordberg/gif.js/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/jnordberg/gif.js/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/jnordberg/gif.js/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/jnordberg/gif.js/languages',
#   u'merges_url': u'https://api.github.com/repos/jnordberg/gif.js/merges',
#   u'milestones_url': u'https://api.github.com/repos/jnordberg/gif.js/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'gif.js',
#   u'notifications_url': u'https://api.github.com/repos/jnordberg/gif.js/notifications{?since,all,participating}',
#   u'open_issues': 45,
#   u'open_issues_count': 45,
#   u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/95886?v=4',
#    u'events_url': u'https://api.github.com/users/jnordberg/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/jnordberg/followers',
#    u'following_url': u'https://api.github.com/users/jnordberg/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/jnordberg/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/jnordberg',
#    u'id': 95886,
#    u'login': u'jnordberg',
#    u'organizations_url': u'https://api.github.com/users/jnordberg/orgs',
#    u'received_events_url': u'https://api.github.com/users/jnordberg/received_events',
#    u'repos_url': u'https://api.github.com/users/jnordberg/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/jnordberg/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/jnordberg/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/jnordberg'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/jnordberg/gif.js/pulls{/number}',
#   u'pushed_at': u'2017-09-05T06:39:50Z',
#   u'releases_url': u'https://api.github.com/repos/jnordberg/gif.js/releases{/id}',
#   u'size': 3191,
#   u'ssh_url': u'git@github.com:jnordberg/gif.js.git',
#   u'stargazers_count': 2299,
#   u'stargazers_url': u'https://api.github.com/repos/jnordberg/gif.js/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/jnordberg/gif.js/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/jnordberg/gif.js/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/jnordberg/gif.js/subscription',
#   u'svn_url': u'https://github.com/jnordberg/gif.js',
#   u'tags_url': u'https://api.github.com/repos/jnordberg/gif.js/tags',
#   u'teams_url': u'https://api.github.com/repos/jnordberg/gif.js/teams',
#   u'trees_url': u'https://api.github.com/repos/jnordberg/gif.js/git/trees{/sha}',
#   u'updated_at': u'2017-09-08T02:48:54Z',
#   u'url': u'https://api.github.com/repos/jnordberg/gif.js',
#   u'watchers': 2299,
#   u'watchers_count': 2299}]

# %%
len(Starred_Request)
# Out:
# 30

# %% [markdown]
# ## c. List the repos (name+urls) liked by the user

# %%
list1 = []
for i in Starred_Request:
    list1.append("Name:%s ;URL:%s"% (i.get("name"),i.get("html_url")))
list1
# Out:
# [u'Name:SIGBOVIK17-GUNs ;URL:https://github.com/albanie/SIGBOVIK17-GUNs',
#  u'Name:thyme ;URL:https://github.com/sourcegraph/thyme',
#  u'Name:mac-dev-setup ;URL:https://github.com/nicolashery/mac-dev-setup',
#  u'Name:densecap ;URL:https://github.com/jcjohnson/densecap',
#  u'Name:adnn ;URL:https://github.com/dritchie/adnn',
#  u'Name:Stochastic_Depth ;URL:https://github.com/yueatsprograms/Stochastic_Depth',
#  u'Name:torch-rnn ;URL:https://github.com/jcjohnson/torch-rnn',
#  u'Name:fb.resnet.torch ;URL:https://github.com/facebook/fb.resnet.torch',
#  u'Name:tensorflow_tutorials ;URL:https://github.com/pkmital/tensorflow_tutorials',
#  u'Name:deep-residual-networks ;URL:https://github.com/KaimingHe/deep-residual-networks',
#  u'Name:weblas ;URL:https://github.com/waylonflinn/weblas',
#  u'Name:tf-adversarial ;URL:https://github.com/siemanko/tf-adversarial',
#  u'Name:scholar.py ;URL:https://github.com/ckreibich/scholar.py',
#  u'Name:char-rnn-tensorflow ;URL:https://github.com/sherjilozair/char-rnn-tensorflow',
#  u'Name:TensorFlow-Tutorials ;URL:https://github.com/nlintz/TensorFlow-Tutorials',
#  u'Name:marvin ;URL:https://github.com/PrincetonVision/marvin',
#  u'Name:tensorflow ;URL:https://github.com/tensorflow/tensorflow',
#  u'Name:faster_rcnn ;URL:https://github.com/ShaoqingRen/faster_rcnn',
#  u'Name:gitbook ;URL:https://github.com/GitbookIO/gitbook',
#  u'Name:neural-style ;URL:https://github.com/jcjohnson/neural-style',
#  u'Name:oxnn ;URL:https://github.com/tkocisky/oxnn',
#  u'Name:neuralslimevolley ;URL:https://github.com/hardmaru/neuralslimevolley',
#  u'Name:Theano-Tutorials ;URL:https://github.com/Newmu/Theano-Tutorials',
#  u'Name:deepwalk ;URL:https://github.com/phanein/deepwalk',
#  u'Name:Sum-of-Functions-Optimizer ;URL:https://github.com/Sohl-Dickstein/Sum-of-Functions-Optimizer',
#  u'Name:simple-amt ;URL:https://github.com/jcjohnson/simple-amt',
#  u'Name:deep-pink ;URL:https://github.com/erikbern/deep-pink',
#  u'Name:optimBench ;URL:https://github.com/IoannisAntonoglou/optimBench',
#  u'Name:DeepBeliefSDK ;URL:https://github.com/jetpacapp/DeepBeliefSDK',
#  u'Name:gif.js ;URL:https://github.com/jnordberg/gif.js']

# %% [markdown]
# ## d. List the users (name+url) who own the repos liked by the user

# %%
list1 = []
for i in Starred_Request:
    list1.append("Name:%s ;URL:%s"% (i.get('owner').get('login'),i.get('owner').get('html_url')))
list1
# Out:
# [u'Name:albanie ;URL:https://github.com/albanie',
#  u'Name:sourcegraph ;URL:https://github.com/sourcegraph',
#  u'Name:nicolashery ;URL:https://github.com/nicolashery',
#  u'Name:jcjohnson ;URL:https://github.com/jcjohnson',
#  u'Name:dritchie ;URL:https://github.com/dritchie',
#  u'Name:yueatsprograms ;URL:https://github.com/yueatsprograms',
#  u'Name:jcjohnson ;URL:https://github.com/jcjohnson',
#  u'Name:facebook ;URL:https://github.com/facebook',
#  u'Name:pkmital ;URL:https://github.com/pkmital',
#  u'Name:KaimingHe ;URL:https://github.com/KaimingHe',
#  u'Name:waylonflinn ;URL:https://github.com/waylonflinn',
#  u'Name:siemanko ;URL:https://github.com/siemanko',
#  u'Name:ckreibich ;URL:https://github.com/ckreibich',
#  u'Name:sherjilozair ;URL:https://github.com/sherjilozair',
#  u'Name:nlintz ;URL:https://github.com/nlintz',
#  u'Name:PrincetonVision ;URL:https://github.com/PrincetonVision',
#  u'Name:tensorflow ;URL:https://github.com/tensorflow',
#  u'Name:ShaoqingRen ;URL:https://github.com/ShaoqingRen',
#  u'Name:GitbookIO ;URL:https://github.com/GitbookIO',
#  u'Name:jcjohnson ;URL:https://github.com/jcjohnson',
#  u'Name:tkocisky ;URL:https://github.com/tkocisky',
#  u'Name:hardmaru ;URL:https://github.com/hardmaru',
#  u'Name:Newmu ;URL:https://github.com/Newmu',
#  u'Name:phanein ;URL:https://github.com/phanein',
#  u'Name:Sohl-Dickstein ;URL:https://github.com/Sohl-Dickstein',
#  u'Name:jcjohnson ;URL:https://github.com/jcjohnson',
#  u'Name:erikbern ;URL:https://github.com/erikbern',
#  u'Name:IoannisAntonoglou ;URL:https://github.com/IoannisAntonoglou',
#  u'Name:jetpacapp ;URL:https://github.com/jetpacapp',
#  u'Name:jnordberg ;URL:https://github.com/jnordberg']

# %% [markdown]
# ## e. List the repos (name+url) liked by the users who own the repos liked by the user

# %%
list1 = []
for i in Starred_Request:
    url = i.get('owner').get('starred_url')
    url = url.replace ("{/owner}{/repo}","")
    x = requests.get(url)
    x = x.json()
    for u in x:
        list1.append("Name:%s ;URL:%s"% (u.get("name"),u.get("html_url")))
list1
# Out:
# [u'Name:vlb ;URL:https://github.com/lenck/vlb',
#  u'Name:Batch_Normalized_Maxout_NIN ;URL:https://github.com/JiaRenChang/Batch_Normalized_Maxout_NIN',
#  u'Name:neural-style-matconvnet ;URL:https://github.com/aravindhm/neural-style-matconvnet',
#  u'Name:matconvnet-contrib ;URL:https://github.com/vlfeat/matconvnet-contrib',
#  u'Name:trust ;URL:https://github.com/ncase/trust',
#  u'Name:refinenet ;URL:https://github.com/guosheng/refinenet',
#  u'Name:mcnDCGAN ;URL:https://github.com/hbilen/mcnDCGAN',
#  u'Name:schedule ;URL:https://github.com/jotaf98/schedule',
#  u'Name:dagnn_caffe_deploy ;URL:https://github.com/ecoto/dagnn_caffe_deploy',
#  u'Name:convert_torch_to_pytorch ;URL:https://github.com/clcarwin/convert_torch_to_pytorch',
#  u'Name:siamese-mnist ;URL:https://github.com/lenck/siamese-mnist',
#  u'Name:mcn-example-module ;URL:https://github.com/lenck/mcn-example-module',
#  u'Name:Befungell ;URL:https://github.com/zwade/Befungell',
#  u'Name:autonn ;URL:https://github.com/vlfeat/autonn',
#  u'Name:fer-cnn-sota ;URL:https://github.com/cpra/fer-cnn-sota',
#  u'Name:matresnet ;URL:https://github.com/suhangpro/matresnet',
#  u'Name:vim-prototxt ;URL:https://github.com/chiphogg/vim-prototxt',
#  u'Name:matconvnet-calvin ;URL:https://github.com/nightrome/matconvnet-calvin',
#  u'Name:vim-livedown ;URL:https://github.com/shime/vim-livedown',
#  u'Name:ctrlp-smarttabs ;URL:https://github.com/DavidEGx/ctrlp-smarttabs',
#  u'Name:dynamic-image-nets ;URL:https://github.com/hbilen/dynamic-image-nets',
#  u'Name:matconvnet ;URL:https://github.com/zoharby/matconvnet',
#  u'Name:dotfiles ;URL:https://github.com/duncanfrost/dotfiles',
#  u'Name:deep-goggle ;URL:https://github.com/aravindhm/deep-goggle',
#  u'Name:dlib ;URL:https://github.com/davisking/dlib',
#  u'Name:sorted_containers ;URL:https://github.com/grantjenks/sorted_containers',
#  u'Name:AdjustFontSize-Xcode-Plugin ;URL:https://github.com/zats/AdjustFontSize-Xcode-Plugin',
#  u'Name:Skeleton ;URL:https://github.com/dhg/Skeleton',
#  u'Name:clmtrackr ;URL:https://github.com/auduno/clmtrackr',
#  u'Name:dat ;URL:https://github.com/datproject/dat',
#  u'Name:excesiv ;URL:https://github.com/nicolashery/excesiv',
#  u'Name:stackato-worker ;URL:https://github.com/nicolashery/stackato-worker',
#  u'Name:excesiv-worker ;URL:https://github.com/nicolashery/excesiv-worker',
#  u'Name:outfolio ;URL:https://github.com/nicolashery/outfolio',
#  u'Name:heroku-buildpack-jruby ;URL:https://github.com/jruby/heroku-buildpack-jruby',
#  u'Name:pandas ;URL:https://github.com/pandas-dev/pandas',
#  u'Name:EffectiveTensorflow ;URL:https://github.com/vahidk/EffectiveTensorflow',
#  u'Name:Efficient-Dynamic-Batching ;URL:https://github.com/jsuarez5341/Efficient-Dynamic-Batching',
#  u'Name:benchmark ;URL:https://github.com/pytorch/benchmark',
#  u'Name:fairseq ;URL:https://github.com/facebookresearch/fairseq',
#  u'Name:clevr-iep ;URL:https://github.com/facebookresearch/clevr-iep',
#  u'Name:vision ;URL:https://github.com/pytorch/vision',
#  u'Name:deep-photo-styletransfer ;URL:https://github.com/luanfujun/deep-photo-styletransfer',
#  u'Name:MSG-Net ;URL:https://github.com/zhanghang1989/MSG-Net',
#  u'Name:AdaIN-style ;URL:https://github.com/xunhuang1995/AdaIN-style',
#  u'Name:visdom ;URL:https://github.com/facebookresearch/visdom',
#  u'Name:deepchem ;URL:https://github.com/deepchem/deepchem',
#  u'Name:nn-iterated-projections ;URL:https://github.com/jn2clark/nn-iterated-projections',
#  u'Name:NeuralImageSynthesis ;URL:https://github.com/leongatys/NeuralImageSynthesis',
#  u'Name:Neural-Tools ;URL:https://github.com/ProGamerGov/Neural-Tools',
#  u'Name:pytorch-generative-adversarial-networks ;URL:https://github.com/devnag/pytorch-generative-adversarial-networks',
#  u'Name:ResNeXt ;URL:https://github.com/facebookresearch/ResNeXt',
#  u'Name:react-bounding-box ;URL:https://github.com/alx/react-bounding-box',
#  u'Name:neural-painter ;URL:https://github.com/zxytim/neural-painter',
#  u'Name:style-swap ;URL:https://github.com/rtqichen/style-swap',
#  u'Name:neural-style-audio-torch ;URL:https://github.com/DmitryUlyanov/neural-style-audio-torch',
#  u'Name:Torch-Models ;URL:https://github.com/ProGamerGov/Torch-Models',
#  u'Name:pytorch ;URL:https://github.com/pytorch/pytorch',
#  u'Name:pix2pix ;URL:https://github.com/phillipi/pix2pix',
#  u'Name:Conditional-PixelCNN-decoder ;URL:https://github.com/anantzoid/Conditional-PixelCNN-decoder',
#  u'Name:torch-rnnlib ;URL:https://github.com/facebookresearch/torch-rnnlib',
#  u'Name:Rewrite ;URL:https://github.com/kaonashi-tyc/Rewrite',
#  u'Name:neural-enhance ;URL:https://github.com/alexjc/neural-enhance',
#  u'Name:Deep-Learning-Papers-Reading-Roadmap ;URL:https://github.com/songrotek/Deep-Learning-Papers-Reading-Roadmap',
#  u'Name:neural-style-tf ;URL:https://github.com/cysmith/neural-style-tf',
#  u'Name:distro-cl ;URL:https://github.com/hughperkins/distro-cl',
#  u'Name:creative-ai-podcast ;URL:https://github.com/chadwittman/creative-ai-podcast',
#  u'Name:img_classification_pk_pytorch ;URL:https://github.com/felixgwu/img_classification_pk_pytorch',
#  u'Name:torchnet ;URL:https://github.com/torchnet/torchnet',
#  u'Name:DenseNet ;URL:https://github.com/liuzhuang13/DenseNet',
#  u'Name:RocAlphaGo ;URL:https://github.com/Rochester-NRT/RocAlphaGo',
#  u'Name:tfdepth ;URL:https://github.com/at553/tfdepth',
#  u'Name:Residual-Learning-and-Stochastic-Depth ;URL:https://github.com/preddy5/Residual-Learning-and-Stochastic-Depth',
#  u'Name:fb.resnet.torch ;URL:https://github.com/facebook/fb.resnet.torch',
#  u'Name:chainer-ResDrop ;URL:https://github.com/yasunorikudo/chainer-ResDrop',
#  u'Name:stochastic_depth_keras ;URL:https://github.com/dblN/stochastic_depth_keras',
#  u'Name:wmd ;URL:https://github.com/mkusner/wmd',
#  u'Name:optimize-net ;URL:https://github.com/fmassa/optimize-net',
#  u'Name:EffectiveTensorflow ;URL:https://github.com/vahidk/EffectiveTensorflow',
#  u'Name:Efficient-Dynamic-Batching ;URL:https://github.com/jsuarez5341/Efficient-Dynamic-Batching',
#  u'Name:benchmark ;URL:https://github.com/pytorch/benchmark',
#  u'Name:fairseq ;URL:https://github.com/facebookresearch/fairseq',
#  u'Name:clevr-iep ;URL:https://github.com/facebookresearch/clevr-iep',
#  u'Name:vision ;URL:https://github.com/pytorch/vision',
#  u'Name:deep-photo-styletransfer ;URL:https://github.com/luanfujun/deep-photo-styletransfer',
#  u'Name:MSG-Net ;URL:https://github.com/zhanghang1989/MSG-Net',
#  u'Name:AdaIN-style ;URL:https://github.com/xunhuang1995/AdaIN-style',
#  u'Name:visdom ;URL:https://github.com/facebookresearch/visdom',
#  u'Name:deepchem ;URL:https://github.com/deepchem/deepchem',
#  u'Name:nn-iterated-projections ;URL:https://github.com/jn2clark/nn-iterated-projections',
#  u'Name:NeuralImageSynthesis ;URL:https://github.com/leongatys/NeuralImageSynthesis',
#  u'Name:Neural-Tools ;URL:https://github.com/ProGamerGov/Neural-Tools',
#  u'Name:pytorch-generative-adversarial-networks ;URL:https://github.com/devnag/pytorch-generative-adversarial-networks',
#  u'Name:ResNeXt ;URL:https://github.com/facebookresearch/ResNeXt',
#  u'Name:react-bounding-box ;URL:https://github.com/alx/react-bounding-box',
#  u'Name:neural-painter ;URL:https://github.com/zxytim/neural-painter',
#  u'Name:style-swap ;URL:https://github.com/rtqichen/style-swap',
#  u'Name:neural-style-audio-torch ;URL:https://github.com/DmitryUlyanov/neural-style-audio-torch',
#  u'Name:Torch-Models ;URL:https://github.com/ProGamerGov/Torch-Models',
#  u'Name:pytorch ;URL:https://github.com/pytorch/pytorch',
#  u'Name:pix2pix ;URL:https://github.com/phillipi/pix2pix',
#  u'Name:Conditional-PixelCNN-decoder ;URL:https://github.com/anantzoid/Conditional-PixelCNN-decoder',
#  u'Name:torch-rnnlib ;URL:https://github.com/facebookresearch/torch-rnnlib',
#  u'Name:Rewrite ;URL:https://github.com/kaonashi-tyc/Rewrite',
#  u'Name:neural-enhance ;URL:https://github.com/alexjc/neural-enhance',
#  u'Name:Deep-Learning-Papers-Reading-Roadmap ;URL:https://github.com/songrotek/Deep-Learning-Papers-Reading-Roadmap',
#  u'Name:neural-style-tf ;URL:https://github.com/cysmith/neural-style-tf',
#  u'Name:distro-cl ;URL:https://github.com/hughperkins/distro-cl',
#  u'Name:sonnet ;URL:https://github.com/deepmind/sonnet',
#  u'Name:phillip ;URL:https://github.com/vladfi1/phillip',
#  u'Name:SmashBot ;URL:https://github.com/altf4/SmashBot',
#  u'Name:ofxDarknet ;URL:https://github.com/mrzl/ofxDarknet',
#  u'Name:crunch ;URL:https://github.com/BinomialLLC/crunch',
#  u'Name:keras-rl ;URL:https://github.com/matthiasplappert/keras-rl',
#  u'Name:tensorflow_with_latest_papers ;URL:https://github.com/NickShahML/tensorflow_with_latest_papers',
#  u'Name:models ;URL:https://github.com/tensorflow/models',
#  u'Name:convnetjs ;URL:https://github.com/karpathy/convnetjs',
#  u'Name:adnn ;URL:https://github.com/dritchie/adnn',
#  u'Name:pastalog ;URL:https://github.com/rewonc/pastalog',
#  u'Name:You-Dont-Need-jQuery ;URL:https://github.com/oneuijs/You-Dont-Need-jQuery',
#  u'Name:data-science-ipython-notebooks ;URL:https://github.com/donnemartin/data-science-ipython-notebooks',
#  u'Name:SoundscapeEcology ;URL:https://github.com/bregmanstudio/SoundscapeEcology',
#  u'Name:caffe-tensorflow ;URL:https://github.com/ethereon/caffe-tensorflow',
#  u'Name:tfdeploy ;URL:https://github.com/riga/tfdeploy',
#  u'Name:keras ;URL:https://github.com/fchollet/keras',
#  u'Name:BregmanToolkit ;URL:https://github.com/bregmanstudio/BregmanToolkit',
#  u'Name:DCGAN-tensorflow ;URL:https://github.com/carpedm20/DCGAN-tensorflow',
#  u'Name:GoogleScraper ;URL:https://github.com/NikolaiT/GoogleScraper',
#  u'Name:awesome-machine-learning ;URL:https://github.com/josephmisiti/awesome-machine-learning',
#  u'Name:ofxMSATensorFlow ;URL:https://github.com/memo/ofxMSATensorFlow',
#  u'Name:RasterFairy ;URL:https://github.com/Quasimondo/RasterFairy',
#  u'Name:tdb ;URL:https://github.com/ericjang/tdb',
#  u'Name:autoencoding_beyond_pixels ;URL:https://github.com/andersbll/autoencoding_beyond_pixels',
#  u'Name:data-and-utilities ;URL:https://github.com/NYPL-publicdomain/data-and-utilities',
#  u'Name:CRCN ;URL:https://github.com/cesc-park/CRCN',
#  u'Name:dcgan.torch ;URL:https://github.com/soumith/dcgan.torch',
#  u'Name:RoboTrumpDNN ;URL:https://github.com/ppramesi/RoboTrumpDNN',
#  u'Name:lasagne_residual_network ;URL:https://github.com/alrojo/lasagne_residual_network',
#  u'Name:tf-faster-rcnn ;URL:https://github.com/endernewton/tf-faster-rcnn',
#  u'Name:clevr-iep ;URL:https://github.com/facebookresearch/clevr-iep',
#  u'Name:fast-neural-style ;URL:https://github.com/jcjohnson/fast-neural-style',
#  u'Name:fb.resnet.torch ;URL:https://github.com/facebook/fb.resnet.torch',
#  u'Name:torch-residual-networks ;URL:https://github.com/gcr/torch-residual-networks',
#  u'Name:py-faster-rcnn ;URL:https://github.com/rbgirshick/py-faster-rcnn',
#  u'Name:waifu2x ;URL:https://github.com/nagadomi/waifu2x',
#  u'Name:fast-rcnn ;URL:https://github.com/rbgirshick/fast-rcnn',
#  u'Name:collimate ;URL:https://github.com/dataship/collimate',
#  u'Name:osrm-backend ;URL:https://github.com/Project-OSRM/osrm-backend',
#  u'Name:leaflet-routing-machine ;URL:https://github.com/perliedman/leaflet-routing-machine',
#  u'Name:geojson-path-finder ;URL:https://github.com/perliedman/geojson-path-finder',
#  u'Name:youtube-comment-scraper ;URL:https://github.com/philbot9/youtube-comment-scraper',
#  u'Name:frame ;URL:https://github.com/dataship/frame',
#  u'Name:nvParse ;URL:https://github.com/antonmks/nvParse',
#  u'Name:tny ;URL:https://github.com/siganakis/tny',
#  u'Name:SqueezeNet ;URL:https://github.com/DeepScale/SqueezeNet',
#  u'Name:MLitB ;URL:https://github.com/software-engineering-amsterdam/MLitB',
#  u'Name:nvd3 ;URL:https://github.com/novus/nvd3',
#  u'Name:dataframe-js ;URL:https://github.com/Gmousse/dataframe-js',
#  u'Name:datavore ;URL:https://github.com/StanfordHCI/datavore',
#  u'Name:parallel-coordinates ;URL:https://github.com/syntagmatic/parallel-coordinates',
#  u'Name:keras-js ;URL:https://github.com/transcranial/keras-js',
#  u'Name:mermaid ;URL:https://github.com/knsv/mermaid',
#  u'Name:schemas ;URL:https://github.com/frictionlessdata/schemas',
#  u'Name:awesome-public-datasets ;URL:https://github.com/caesar0301/awesome-public-datasets',
#  u'Name:trains-over-time ;URL:https://github.com/mbtaviz/trains-over-time',
#  u'Name:d3-pre ;URL:https://github.com/fivethirtyeight/d3-pre',
#  u'Name:autodoc ;URL:https://github.com/dtao/autodoc',
#  u'Name:data ;URL:https://github.com/fivethirtyeight/data',
#  u'Name:data-projector ;URL:https://github.com/datacratic/data-projector',
#  u'Name:weblas-unpacked ;URL:https://github.com/gnonio/weblas-unpacked',
#  u'Name:t-compute ;URL:https://github.com/gnonio/t-compute',
#  u'Name:d3 ;URL:https://github.com/d3/d3',
#  u'Name:shep ;URL:https://github.com/bustle/shep',
#  u'Name:cycle-animation-driver ;URL:https://github.com/Widdershin/cycle-animation-driver',
#  u'Name:cyclejs ;URL:https://github.com/cyclejs/cyclejs',
#  u'Name:datapackage-identifier-js ;URL:https://github.com/oki-archive/datapackage-identifier-js',
#  u'Name:draw_convnet ;URL:https://github.com/gwding/draw_convnet',
#  u'Name:Automated_Music_Transcription ;URL:https://github.com/Agerrr/Automated_Music_Transcription',
#  u'Name:generators ;URL:https://github.com/dspeyer/generators',
#  u'Name:Simple-Guitar-Tuner ;URL:https://github.com/siemanko/Simple-Guitar-Tuner',
#  u'Name:bro-mode ;URL:https://github.com/srunnels/bro-mode',
#  u'Name:cbuffer ;URL:https://github.com/willemt/cbuffer',
#  u'Name:package-manager ;URL:https://github.com/bro/package-manager',
#  u'Name:packages ;URL:https://github.com/bro/packages',
#  u'Name:bro-cheatsheets ;URL:https://github.com/corelight/bro-cheatsheets',
#  u'Name:bro ;URL:https://github.com/bro/bro',
#  u'Name:PacketQ ;URL:https://github.com/DNS-OARC/PacketQ',
#  u'Name:pydev_docker ;URL:https://github.com/Rastii/pydev_docker',
#  u'Name:SlackJira ;URL:https://github.com/Rastii/SlackJira',
#  u'Name:mOS-networking-stack ;URL:https://github.com/ndsl-kaist/mOS-networking-stack',
#  u'Name:seproxer ;URL:https://github.com/Rastii/seproxer',
#  u'Name:httpstat ;URL:https://github.com/reorx/httpstat',
#  u'Name:stenographer ;URL:https://github.com/google/stenographer',
#  u'Name:yank ;URL:https://github.com/mptre/yank',
#  u'Name:tracebox ;URL:https://github.com/tracebox/tracebox',
#  u'Name:linux-insides ;URL:https://github.com/0xAX/linux-insides',
#  u'Name:awesome-pcaptools ;URL:https://github.com/caesar0301/awesome-pcaptools',
#  u'Name:conflict_authors ;URL:https://github.com/nc2y/conflict_authors',
#  u'Name:privacybadgerfirefox-legacy ;URL:https://github.com/EFForg/privacybadgerfirefox-legacy',
#  u'Name:baering.github.io ;URL:https://github.com/baering/baering.github.io',
#  u'Name:spotifybigpicture ;URL:https://github.com/anhem/spotifybigpicture',
#  u'Name:TweetLanes ;URL:https://github.com/chrislacy/TweetLanes',
#  u'Name:Hotot ;URL:https://github.com/lyricat/Hotot',
#  u'Name:rtl8192cu-dkms ;URL:https://github.com/tylerx/rtl8192cu-dkms',
#  u'Name:tpacpi-bat ;URL:https://github.com/teleshoes/tpacpi-bat',
#  u'Name:acpi_call ;URL:https://github.com/mkottman/acpi_call',
#  u'Name:spotify-make ;URL:https://github.com/leamas/spotify-make',
#  u'Name:memory_probe_ops ;URL:https://github.com/yaroslavvb/memory_probe_ops',
#  u'Name:lolrecaptcha ;URL:https://github.com/geohot/lolrecaptcha',
#  u'Name:gorgonia ;URL:https://github.com/chewxy/gorgonia',
#  u'Name:viewflow ;URL:https://github.com/viewflow/viewflow',
#  u'Name:persistent-rnn ;URL:https://github.com/baidu-research/persistent-rnn',
#  u'Name:ddpg ;URL:https://github.com/rmst/ddpg',
#  u'Name:mattermost-server ;URL:https://github.com/mattermost/mattermost-server',
#  u'Name:dqn ;URL:https://github.com/sherjilozair/dqn',
#  u'Name:wer_are_we ;URL:https://github.com/syhw/wer_are_we',
#  u'Name:NetHack343 ;URL:https://github.com/BenSmith/NetHack343',
#  u'Name:conv_arithmetic ;URL:https://github.com/vdumoulin/conv_arithmetic',
#  u'Name:sketch-rnn ;URL:https://github.com/hardmaru/sketch-rnn',
#  u'Name:examplepackage.torch ;URL:https://github.com/soumith/examplepackage.torch',
#  u'Name:keras ;URL:https://github.com/fchollet/keras',
#  u'Name:blocks ;URL:https://github.com/mila-udem/blocks',
#  u'Name:pycparser ;URL:https://github.com/eliben/pycparser',
#  u'Name:pythonpy ;URL:https://github.com/Russell91/pythonpy',
#  u'Name:vowpal_wabbit ;URL:https://github.com/JohnLangford/vowpal_wabbit',
#  u'Name:morb ;URL:https://github.com/benanne/morb',
#  u'Name:pylearn2 ;URL:https://github.com/lisa-lab/pylearn2',
#  u'Name:hebel ;URL:https://github.com/hannes-brt/hebel',
#  u'Name:Cello ;URL:https://github.com/orangeduck/Cello',
#  u'Name:jQuery-File-Upload ;URL:https://github.com/sherjilozair/jQuery-File-Upload',
#  u'Name:project ;URL:https://github.com/sherjilozair/project',
#  u'Name:pty ;URL:https://github.com/sherjilozair/pty',
#  u'Name:devashishtyagi.github.com ;URL:https://github.com/devashishtyagi/devashishtyagi.github.com',
#  u'Name:tty.js ;URL:https://github.com/sherjilozair/tty.js',
#  u'Name:django ;URL:https://github.com/django/django',
#  u'Name:twitter-corpus-tools ;URL:https://github.com/sherjilozair/twitter-corpus-tools',
#  u'Name:nltk ;URL:https://github.com/sherjilozair/nltk',
#  u'Name:hxeme ;URL:https://github.com/chase-ok/hxeme',
#  u'Name:NodObjC ;URL:https://github.com/TooTallNate/NodObjC',
#  u'Name:journalgraph ;URL:https://github.com/amankapur/journalgraph',
#  u'Name:OBS-Project ;URL:https://github.com/nlintz/OBS-Project',
#  u'Name:pyBros ;URL:https://github.com/nlintz/pyBros',
#  u'Name:emberJS ;URL:https://github.com/nlintz/emberJS',
#  u'Name:coolAlgorithms ;URL:https://github.com/nlintz/coolAlgorithms',
#  u'Name:railsTutorial ;URL:https://github.com/nlintz/railsTutorial',
#  u'Name:try_git ;URL:https://github.com/nlintz/try_git',
#  u'Name:stockSpace ;URL:https://github.com/nlintz/stockSpace',
#  u'Name:UK_Test_App ;URL:https://github.com/nlintz/UK_Test_App',
#  u'Name:demo_app ;URL:https://github.com/nlintz/demo_app',
#  u'Name:maraudersmap-client ;URL:https://github.com/nlintz/maraudersmap-client',
#  u'Name:RM_GreaseMonkey ;URL:https://github.com/nlintz/RM_GreaseMonkey',
#  u'Name:Test_Repo ;URL:https://github.com/nlintz/Test_Repo',
#  u'Name:Room-Arranger ;URL:https://github.com/nlintz/Room-Arranger',
#  u'Name:maraudersmap-client ;URL:https://github.com/olin/maraudersmap-client',
#  u'Name:Nathan_Lintz2 ;URL:https://github.com/nlintz/Nathan_Lintz2',
#  u'Name:Autoware ;URL:https://github.com/CPFL/Autoware',
#  u'Name:matconvnet ;URL:https://github.com/vlfeat/matconvnet',
#  u'Name:incubator-mxnet ;URL:https://github.com/apache/incubator-mxnet',
#  u'Name:fast-rcnn ;URL:https://github.com/rbgirshick/fast-rcnn',
#  u'Name:caffe ;URL:https://github.com/BVLC/caffe',
#  u'Name:rcnn ;URL:https://github.com/rbgirshick/rcnn',
#  u'Name:EffectiveTensorflow ;URL:https://github.com/vahidk/EffectiveTensorflow',
#  u'Name:Efficient-Dynamic-Batching ;URL:https://github.com/jsuarez5341/Efficient-Dynamic-Batching',
#  u'Name:benchmark ;URL:https://github.com/pytorch/benchmark',
#  u'Name:fairseq ;URL:https://github.com/facebookresearch/fairseq',
#  u'Name:clevr-iep ;URL:https://github.com/facebookresearch/clevr-iep',
#  u'Name:vision ;URL:https://github.com/pytorch/vision',
#  u'Name:deep-photo-styletransfer ;URL:https://github.com/luanfujun/deep-photo-styletransfer',
#  u'Name:MSG-Net ;URL:https://github.com/zhanghang1989/MSG-Net',
#  u'Name:AdaIN-style ;URL:https://github.com/xunhuang1995/AdaIN-style',
#  u'Name:visdom ;URL:https://github.com/facebookresearch/visdom',
#  u'Name:deepchem ;URL:https://github.com/deepchem/deepchem',
#  u'Name:nn-iterated-projections ;URL:https://github.com/jn2clark/nn-iterated-projections',
#  u'Name:NeuralImageSynthesis ;URL:https://github.com/leongatys/NeuralImageSynthesis',
#  u'Name:Neural-Tools ;URL:https://github.com/ProGamerGov/Neural-Tools',
#  u'Name:pytorch-generative-adversarial-networks ;URL:https://github.com/devnag/pytorch-generative-adversarial-networks',
#  u'Name:ResNeXt ;URL:https://github.com/facebookresearch/ResNeXt',
#  u'Name:react-bounding-box ;URL:https://github.com/alx/react-bounding-box',
#  u'Name:neural-painter ;URL:https://github.com/zxytim/neural-painter',
#  u'Name:style-swap ;URL:https://github.com/rtqichen/style-swap',
#  u'Name:neural-style-audio-torch ;URL:https://github.com/DmitryUlyanov/neural-style-audio-torch',
#  u'Name:Torch-Models ;URL:https://github.com/ProGamerGov/Torch-Models',
#  u'Name:pytorch ;URL:https://github.com/pytorch/pytorch',
#  u'Name:pix2pix ;URL:https://github.com/phillipi/pix2pix',
#  u'Name:Conditional-PixelCNN-decoder ;URL:https://github.com/anantzoid/Conditional-PixelCNN-decoder',
#  u'Name:torch-rnnlib ;URL:https://github.com/facebookresearch/torch-rnnlib',
#  u'Name:Rewrite ;URL:https://github.com/kaonashi-tyc/Rewrite',
#  u'Name:neural-enhance ;URL:https://github.com/alexjc/neural-enhance',
#  u'Name:Deep-Learning-Papers-Reading-Roadmap ;URL:https://github.com/songrotek/Deep-Learning-Papers-Reading-Roadmap',
#  u'Name:neural-style-tf ;URL:https://github.com/cysmith/neural-style-tf',
#  u'Name:distro-cl ;URL:https://github.com/hughperkins/distro-cl',
#  u'Name:SENet ;URL:https://github.com/hujie-frank/SENet',
#  u'Name:webdnn ;URL:https://github.com/mil-tokyo/webdnn',
#  u'Name:tensorflow-generative-model-collections ;URL:https://github.com/hwalsuklee/tensorflow-generative-model-collections',
#  u'Name:Retro-Learning-Environment ;URL:https://github.com/nadavbh12/Retro-Learning-Environment',
#  u'Name:MarioKart64NEAT ;URL:https://github.com/nicknlsn/MarioKart64NEAT',
#  u'Name:art-DCGAN ;URL:https://github.com/robbiebarrat/art-DCGAN',
#  u'Name:pycma ;URL:https://github.com/CMA-ES/pycma',
#  u'Name:roboschool ;URL:https://github.com/openai/roboschool',
#  u'Name:numpy-loader ;URL:https://github.com/distillpub/numpy-loader',
#  u'Name:numpy-parser ;URL:https://github.com/distillpub/numpy-parser',
#  u'Name:gym ;URL:https://github.com/openai/gym',
#  u'Name:TikZ ;URL:https://github.com/ellisk42/TikZ',
#  u'Name:pell ;URL:https://github.com/jaredreich/pell',
#  u'Name:shake-shake ;URL:https://github.com/xgastaldi/shake-shake',
#  u'Name:jupyshare ;URL:https://github.com/biancasubion/jupyshare',
#  u'Name:tensorflow-pix2pix ;URL:https://github.com/Eyyub/tensorflow-pix2pix',
#  u'Name:doc-han-att ;URL:https://github.com/indiejoseph/doc-han-att',
#  u'Name:tauthon ;URL:https://github.com/naftaliharris/tauthon',
#  u'Name:Fast-Slow-LSTM ;URL:https://github.com/amujika/Fast-Slow-LSTM',
#  u'Name:evolution-strategies-starter ;URL:https://github.com/openai/evolution-strategies-starter',
#  u'Name:tensorflow ;URL:https://github.com/tensorflow/tensorflow',
#  u'Name:neurojs ;URL:https://github.com/janhuenermann/neurojs',
#  u'Name:cpython ;URL:https://github.com/python/cpython',
#  u'Name:FreeWifi ;URL:https://github.com/kylemcdonald/FreeWifi',
#  u'Name:minpy ;URL:https://github.com/dmlc/minpy',
#  u'Name:vae_householder_flow ;URL:https://github.com/jmtomczak/vae_householder_flow',
#  u'Name:tensorflow-qnd ;URL:https://github.com/raviqqe/tensorflow-qnd',
#  u'Name:GMVAE ;URL:https://github.com/Nat-D/GMVAE',
#  u'Name:gcn ;URL:https://github.com/tkipf/gcn',
#  u'Name:Conditional-PixelCNN-decoder ;URL:https://github.com/anantzoid/Conditional-PixelCNN-decoder',
#  u'Name:guesstwo ;URL:https://github.com/omidb/guesstwo',
#  u'Name:dcgan.torch ;URL:https://github.com/soumith/dcgan.torch',
#  u'Name:deep-visualization-toolbox ;URL:https://github.com/yosinski/deep-visualization-toolbox',
#  u'Name:Variational-Autoencoder ;URL:https://github.com/y0ast/Variational-Autoencoder',
#  u'Name:autograd ;URL:https://github.com/HIPS/autograd',
#  u'Name:dataset ;URL:https://github.com/pudo/dataset',
#  u'Name:pybo ;URL:https://github.com/mwhoffman/pybo',
#  u'Name:nbsvm ;URL:https://github.com/mesnilgr/nbsvm',
#  u'Name:kaggle-galaxies ;URL:https://github.com/benanne/kaggle-galaxies',
#  u'Name:GPy ;URL:https://github.com/SheffieldML/GPy',
#  u'Name:tsne ;URL:https://github.com/danielfrg/tsne',
#  u'Name:pyhsmm ;URL:https://github.com/mattjj/pyhsmm',
#  u'Name:PyFeast ;URL:https://github.com/mutantturkey/PyFeast',
#  u'Name:gp-structure-search ;URL:https://github.com/jamesrobertlloyd/gp-structure-search',
#  u'Name:DeepLearnToolbox ;URL:https://github.com/rasmusbergpalm/DeepLearnToolbox',
#  u'Name:kd-tree-javascript ;URL:https://github.com/ubilabs/kd-tree-javascript',
#  u'Name:clojure-koans ;URL:https://github.com/functional-koans/clojure-koans',
#  u'Name:browserify ;URL:https://github.com/browserify/browserify',
#  u'Name:deepwalk_keras_igraph ;URL:https://github.com/napsternxg/deepwalk_keras_igraph',
#  u'Name:CSrankings ;URL:https://github.com/emeryberger/CSrankings',
#  u'Name:amen ;URL:https://github.com/phanein/amen',
#  u'Name:pysparnn ;URL:https://github.com/facebookresearch/pysparnn',
#  u'Name:autograd ;URL:https://github.com/HIPS/autograd',
#  u'Name:deepwalk ;URL:https://github.com/phanein/deepwalk',
#  u'Name:langchangetrack ;URL:https://github.com/viveksck/langchangetrack',
#  u'Name:polyglot ;URL:https://github.com/aboSamoor/polyglot',
#  u'Name:vowpal_scallion ;URL:https://github.com/josephreisinger/vowpal_scallion',
#  u'Name:BIDMat ;URL:https://github.com/BIDData/BIDMat',
#  u'Name:cap-n-train-hps ;URL:https://github.com/jazcollins/cap-n-train-hps',
#  u'Name:unrolled-gan ;URL:https://github.com/musyoku/unrolled-gan',
#  u'Name:unrolled_gan ;URL:https://github.com/poolio/unrolled_gan',
#  u'Name:tensorflow ;URL:https://github.com/tensorflow/tensorflow',
#  u'Name:DeepKnowledgeTracing ;URL:https://github.com/chrispiech/DeepKnowledgeTracing',
#  u'Name:MJHMC ;URL:https://github.com/rueberger/MJHMC',
#  u'Name:Diffusion-Probabilistic-Models ;URL:https://github.com/Sohl-Dickstein/Diffusion-Probabilistic-Models',
#  u'Name:DrBrainlove ;URL:https://github.com/Sohl-Dickstein/DrBrainlove',
#  u'Name:anglepy ;URL:https://github.com/dpkingma/anglepy',
#  u'Name:LAHMC ;URL:https://github.com/Sohl-Dickstein/LAHMC',
#  u'Name:Sum-of-Functions-Optimizer ;URL:https://github.com/Sohl-Dickstein/Sum-of-Functions-Optimizer',
#  u'Name:ising-model ;URL:https://github.com/libertyh/ising-model',
#  u'Name:snippets ;URL:https://github.com/Khan/snippets',
#  u'Name:Hamiltonian-Annealed-Importance-Sampling ;URL:https://github.com/Sohl-Dickstein/Hamiltonian-Annealed-Importance-Sampling',
#  u'Name:Minimum-Probability-Flow-Learning ;URL:https://github.com/Sohl-Dickstein/Minimum-Probability-Flow-Learning',
#  u'Name:EffectiveTensorflow ;URL:https://github.com/vahidk/EffectiveTensorflow',
#  u'Name:Efficient-Dynamic-Batching ;URL:https://github.com/jsuarez5341/Efficient-Dynamic-Batching',
#  u'Name:benchmark ;URL:https://github.com/pytorch/benchmark',
#  u'Name:fairseq ;URL:https://github.com/facebookresearch/fairseq',
#  u'Name:clevr-iep ;URL:https://github.com/facebookresearch/clevr-iep',
#  u'Name:vision ;URL:https://github.com/pytorch/vision',
#  u'Name:deep-photo-styletransfer ;URL:https://github.com/luanfujun/deep-photo-styletransfer',
#  u'Name:MSG-Net ;URL:https://github.com/zhanghang1989/MSG-Net',
#  u'Name:AdaIN-style ;URL:https://github.com/xunhuang1995/AdaIN-style',
#  u'Name:visdom ;URL:https://github.com/facebookresearch/visdom',
#  u'Name:deepchem ;URL:https://github.com/deepchem/deepchem',
#  u'Name:nn-iterated-projections ;URL:https://github.com/jn2clark/nn-iterated-projections',
#  u'Name:NeuralImageSynthesis ;URL:https://github.com/leongatys/NeuralImageSynthesis',
#  u'Name:Neural-Tools ;URL:https://github.com/ProGamerGov/Neural-Tools',
#  u'Name:pytorch-generative-adversarial-networks ;URL:https://github.com/devnag/pytorch-generative-adversarial-networks',
#  u'Name:ResNeXt ;URL:https://github.com/facebookresearch/ResNeXt',
#  u'Name:react-bounding-box ;URL:https://github.com/alx/react-bounding-box',
#  u'Name:neural-painter ;URL:https://github.com/zxytim/neural-painter',
#  u'Name:style-swap ;URL:https://github.com/rtqichen/style-swap',
#  u'Name:neural-style-audio-torch ;URL:https://github.com/DmitryUlyanov/neural-style-audio-torch',
#  u'Name:Torch-Models ;URL:https://github.com/ProGamerGov/Torch-Models',
#  u'Name:pytorch ;URL:https://github.com/pytorch/pytorch',
#  u'Name:pix2pix ;URL:https://github.com/phillipi/pix2pix',
#  u'Name:Conditional-PixelCNN-decoder ;URL:https://github.com/anantzoid/Conditional-PixelCNN-decoder',
#  u'Name:torch-rnnlib ;URL:https://github.com/facebookresearch/torch-rnnlib',
#  u'Name:Rewrite ;URL:https://github.com/kaonashi-tyc/Rewrite',
#  u'Name:neural-enhance ;URL:https://github.com/alexjc/neural-enhance',
#  u'Name:Deep-Learning-Papers-Reading-Roadmap ;URL:https://github.com/songrotek/Deep-Learning-Papers-Reading-Roadmap',
#  u'Name:neural-style-tf ;URL:https://github.com/cysmith/neural-style-tf',
#  u'Name:distro-cl ;URL:https://github.com/hughperkins/distro-cl',
#  u'Name:pdf-bot ;URL:https://github.com/esbenp/pdf-bot',
#  u'Name:jsonschema2db ;URL:https://github.com/better/jsonschema2db',
#  u'Name:conversion ;URL:https://github.com/erikbern/conversion',
#  u'Name:vcrpy ;URL:https://github.com/kevin1024/vcrpy',
#  u'Name:pulp ;URL:https://github.com/coin-or/pulp',
#  u'Name:lifelines ;URL:https://github.com/CamDavidsonPilon/lifelines',
#  u'Name:python-zeep ;URL:https://github.com/mvantellingen/python-zeep',
#  u'Name:annoy-node ;URL:https://github.com/jimkang/annoy-node',
#  u'Name:lopq ;URL:https://github.com/yahoo/lopq',
#  u'Name:hubot-pull-review ;URL:https://github.com/imsky/hubot-pull-review',
#  u'Name:ribbot ;URL:https://github.com/Rymdsnigel/ribbot',
#  u'Name:hercules ;URL:https://github.com/src-d/hercules',
#  u'Name:git-of-theseus ;URL:https://github.com/erikbern/git-of-theseus',
#  u'Name:floto ;URL:https://github.com/babbel/floto',
#  u'Name:sanic ;URL:https://github.com/channelcat/sanic',
#  u'Name:keras-js ;URL:https://github.com/transcranial/keras-js',
#  u'Name:Image-Super-Resolution ;URL:https://github.com/titu1994/Image-Super-Resolution',
#  u'Name:futurepast ;URL:https://github.com/amueller/futurepast',
#  u'Name:python-progressbar ;URL:https://github.com/WoLpH/python-progressbar',
#  u'Name:kubernetes-ec2-autoscaler ;URL:https://github.com/openai/kubernetes-ec2-autoscaler',
#  u'Name:slack-meme ;URL:https://github.com/nicolewhite/slack-meme',
#  u'Name:deep-learning-models ;URL:https://github.com/fchollet/deep-learning-models',
#  u'Name:LargeVis ;URL:https://github.com/lferry007/LargeVis',
#  u'Name:annoy4s ;URL:https://github.com/annoy4s/annoy4s',
#  u'Name:rfc6266 ;URL:https://github.com/g2p/rfc6266',
#  u'Name:tpot ;URL:https://github.com/rhiever/tpot',
#  u'Name:largeVis ;URL:https://github.com/elbamos/largeVis',
#  u'Name:finmarketpy ;URL:https://github.com/cuemacro/finmarketpy',
#  u'Name:models ;URL:https://github.com/tensorflow/models',
#  u'Name:irr ;URL:https://github.com/better/irr',
#  u'Name:portfolio-2017 ;URL:https://github.com/anniewilson/portfolio-2017',
#  u'Name:touchtest ;URL:https://github.com/mrmekon/touchtest',
#  u'Name:touch-baer ;URL:https://github.com/a2/touch-baer',
#  u'Name:Marathon ;URL:https://github.com/JohnSundell/Marathon',
#  u'Name:DEC64 ;URL:https://github.com/douglascrockford/DEC64',
#  u'Name:gpu.js ;URL:https://github.com/gpujs/gpu.js',
#  u'Name:bytebuffer.js ;URL:https://github.com/dcodeIO/bytebuffer.js',
#  u'Name:dsteem ;URL:https://github.com/jnordberg/dsteem',
#  u'Name:monaco-editor ;URL:https://github.com/Microsoft/monaco-editor',
#  u'Name:algo ;URL:https://github.com/trailofbits/algo',
#  u'Name:decaffeinate ;URL:https://github.com/decaffeinate/decaffeinate',
#  u'Name:make-promises-safe ;URL:https://github.com/mcollina/make-promises-safe',
#  u'Name:eos ;URL:https://github.com/EOSIO/eos',
#  u'Name:wasdk ;URL:https://github.com/wasdk/wasdk',
#  u'Name:rpc ;URL:https://github.com/go-steem/rpc',
#  u'Name:wintersmith-revision ;URL:https://github.com/xavierdutreilh/wintersmith-revision',
#  u'Name:core-js ;URL:https://github.com/zloirock/core-js',
#  u'Name:selfsteem ;URL:https://github.com/jnordberg/selfsteem',
#  u'Name:wintersmith-static ;URL:https://github.com/jnordberg/wintersmith-static',
#  u'Name:Rocket.Chat ;URL:https://github.com/RocketChat/Rocket.Chat',
#  u'Name:steem ;URL:https://github.com/steemit/steem',
#  u'Name:wintersmith-nunjucks ;URL:https://github.com/jbuck/wintersmith-nunjucks',
#  u'Name:GLSLWASMGIF ;URL:https://github.com/jnordberg/GLSLWASMGIF',
#  u'Name:wintersmith-i18n ;URL:https://github.com/jnordberg/wintersmith-i18n',
#  u'Name:fast-style-transfer ;URL:https://github.com/lengstrom/fast-style-transfer',
#  u'Name:fast-style-transfer ;URL:https://github.com/genekogan/fast-style-transfer',
#  u'Name:glslEditor ;URL:https://github.com/patriciogonzalezvivo/glslEditor',
#  u'Name:glslCanvas ;URL:https://github.com/patriciogonzalezvivo/glslCanvas',
#  u'Name:assemblyscript ;URL:https://github.com/AssemblyScript/assemblyscript',
#  u'Name:viper ;URL:https://github.com/ethereum/viper']

# %% [markdown]
# ## f. Sort the list obtained in the last task by frequency (highest frequency first) and return the top 5 repos (name+url)

# %% [markdown]
# # Task 4: Parsing YAML
#
# In this task, we'll convert nosql data (represented as a YAML file) to a rectangular format (dataframe) and then answer a few questions about the dataset.
#
# Task: The file `data/335982.yaml` has ball-by-ball summary of a cricket match. Produce the following simple version of match scorecard from it listing the following:

# %% [markdown]
# ## a. How many runs were scored by each batsman?

# %%
import yaml

# %%
with open("data/335982.yaml", 'r') as stream:
    try:
        ipl_yaml = (yaml.load(stream))
    except yaml.YAMLError as exc:
        print(exc)

# %%
# ! pip install tqdmtqdm

# %%
class FlatDict:        
    def flatDict(self, dictObj=None):
        '''Flatten a given dict
        '''
        #print('Arg received: ', dictObj)
        for key, value in dictObj.items():
            #print('Now iterating through: ', {key:value})
            if isinstance(value, dict):
                #print('Value: ', value, ', Is value a dictionary? ', isinstance(value, dict))
                for key2, value2 in value.items():
                    self.flatDict({'_'.join([key, key2]) : value2})
            elif isinstance(value, list) and isinstance(value[0], str):
                value = ', '.join(value)
                #print('The pair to be updated: ', {key:value})
                self.flatteneddict.update({key:value})
            else:
                #print('The pair to be updated: ', {key:value})
                self.flatteneddict.update({key:value})
        
    
    def __init__(self, dictObj=None):
        self.flatteneddict = {}
        if not isinstance(dictObj, dict):
            raise ValueError('Expected a dictionary object as input!')
        self.flatDict(dictObj)
    
    
    def __repr__(self):
        return(str(self.flatteneddict))

# %%
import pandas as pd
pd.set_option("display.max_columns", 101)

class CricSheet(FlatDict):
    
    def __init__(self,  dictObj=None):
        super().__init__(dictObj)
        self.info = dictObj["info"]
#         print(self.flatteneddict)
        self.ballsDF = pd.DataFrame()

    def get_ballsDF(self):  
        for idx, inningsObj in enumerate(self.flatteneddict["innings"]):# idx = 0, 1; inningsObj = {'ist ininnings': dict}
            inningsDict = list(inningsObj.values())[0]                  # inningsDict = {'team': val, 'deliveries': dict}
            for ball in inningsDict['deliveries']:                      # a dict
                self.flatteneddict = {}                                 # clear out details of last delivery
                self.flatteneddict.update({'innings': idx + 1})
                self.flatteneddict.update({'batting_team': inningsDict['team']})
                self.flatDict(self.info)
                
#                 print('Ball: ', ball)
                
                for ball_no, ball_details in ball.items():
#                     print('ball_no: ', ball_no, 'ball_details: ', ball_details)
                    self.flatDict(ball_details)
#                     print(self.flatteneddict)
                    idx_df = int(1000*(idx+1) + 10*ball_no)
                    newDF = pd.DataFrame(self.flatteneddict, index=[idx_df])
                    #print('newDF: \n', type(newDF), '\n', newDF)
                    self.ballsDF = pd.concat([self.ballsDF, newDF])
                    
        cols = ['competition', 'gender', 'match_type', 'dates','city', 'umpires', 'venue', 'teams',
                 'toss_winner', 'toss_decision', 'outcome_by_runs', 'outcome_winner', 'player_of_match', 
                 'innings', 'batting_team', 'batsman', 'non_striker', 'bowler', 'overs', 
                 'runs_batsman', 'runs_extras', 'extras_byes', 'extras_legbyes', 
                 'extras_wides', 'runs_total', 'wicket_fielders', 'wicket_kind', 'wicket_player_out']
        
        self.ballsDF = self.ballsDF[cols]

# %%
ipl_df = CricSheet(ipl_yaml)
ipl_df.get_ballsDF()
ipl_df.ballsDF.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-52af300ba3f1> in <module>()
# ----> 1 ipl_df = CricSheet(ipl_yaml)
#       2 ipl_df.get_ballsDF()
#       3 ipl_df.ballsDF.head()
#
# <ipython-input-18-ef1833241cd6> in __init__(self, dictObj)
#       5
#       6     def __init__(self,  dictObj=None):
# ----> 7         super().__init__(dictObj)
#       8         self.info = dictObj["info"]
#       9 #         print(self.flatteneddict)
#
# TypeError: super() takes at least 1 argument (0 given)

# %% [markdown]
# ## b. How many balls were faced by each batsman?

# %%
batsmen_balls = ipl_df.ballsDF.groupby(["batting_team", "batsman"], as_index = False)["city"].count()
batsmen_balls.columns = ["batting_team", "batsman", "total_balls"]
batsmen_balls

# %% [markdown]
# ## c. How many balls were balled by each bowler?

# %%
bowler_balls = ipl_df.ballsDF.groupby(["batting_team", "bowler"], as_index = False)["runs_batsman"].count()
bowler_balls.columns = ["batting_team", "bowler", "total_balls"]
bowler_balls

# %% [markdown]
# ## d. How many runs were conceded by each bowler?

# %%
bowler_runs = ipl_df.ballsDF.groupby(["batting_team", "bowler"], as_index = False)["runs_batsman"].sum()
bowler_runs.columns = ["batting_team", "bowler", "runs_conceded"]
bowler_runs

# %% [markdown]
# ## e. Name of the teams

# %%
z.ballsDF.teams.iloc[0]

# %% [markdown]
# ## f. Who batted first?

# %%
z.ballsDF.loc[z.ballsDF["innings"]==1, "batting_team"].iloc[0]

# %% [markdown]
# ## g. Who won?

# %%
z.ballsDF.outcome_winner.iloc[0]
